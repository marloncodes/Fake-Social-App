# %% [markdown]
# <a href="https://colab.research.google.com/github/marloncodes/Fake-Social-App/blob/main/Classificacao_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import svm
from  sklearn.metrics import classification_report

# %matplotlib inline

# %%
X,y = load_iris(return_X_y=True)

# %%
iris = load_iris()
iris_pd = pd.DataFrame(data=X, columns=iris.feature_names)
iris_pd['target_name'] = pd.Categorical.from_codes(y,iris.target_names)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
iris_pd
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#     target_name
# ...

# %%
iris_pd.plot.scatter('petal length (cm)','petal width (cm)',c=y ,cmap='cividis')

# %%
sns.pairplot(iris_pd[['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)','target_name']],hue='target_name')

# %%
clf = svm.SVC(C=1.0)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
#Acurácia
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred,target_names=iris.target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
